# %% [markdown]
# # 學習日期: 2022/6/7開始
# ## 目標: 透過LSTM模型，預測庫貨量
# - **參考資料1:** 上次寫的code「LSTM_COVID-19預測」
# - **修改:** 圖表7改成seq_length

# %% [markdown]
# ## 0_修改程式 (傳送門)
# - [數據分析](#1_數據分析)
#
#
# - [數據預處理](#2_數據預處理)
#
#
# - [main-LSTM模型](#3_建立模型-LSTM)
#
#
# - [main-訓練model](#4.1_訓練模型)
#
#
# - [main-調超參數](#4.2_訓練模型-設定超參數)
#
#
# - [預測未來幾天庫存量](#5.1_最佳模型->預測未來幾天庫存量)

# %% [markdown]
# ## 1_數據分析

# %%
import torch
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
#import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.preprocessing import MinMaxScaler
from pandas.plotting import register_matplotlib_converters
from torch import nn, optim
from sklearn.metrics import r2_score  # R_Score

# %%
# https://blog.csdn.net/lht_okk/article/details/54929103
df = pd.read_csv('./data.csv', encoding= 'ANSI')  # 將csv載入到DataFrame中; usecols=指定載入的行名
#df = pd.read_csv('2020-2021_time_series_covid19_confirmed_global.csv', usecols = ["Lat","Long"])
print(df.head())
# Out:
#     日期  2020-1-2  2020-1-9  2020-1-16  2020-1-23  2020-1-30  2020-2-6  \
# 0  在庫量         0         0          0          0          0         0
#
#    2020-2-13  2020-2-20  2020-2-27  ...  2021-11-30  2021-12-2  2021-12-7  \
# 0          0          0          0  ...        3422       3922       3922
#
#    2021-12-9  2021-12-14  2021-12-16  2021-12-21  2021-12-23  2021-12-28  \
# 0       4482        4482        5982        5982        6282        6224
#
#    2021-12-30
# 0        7124
#
# [1 rows x 156 columns]

# %%
df = df.iloc[:,16:]  # 切掉不要的行(column_index)
print(df.head())  # 內容值=0,157841... ;  column_index=2020-1-22... ;  row_index=0,1,2,3
# Out:
#    2020-4-16  2020-4-23  2020-4-30  2020-5-7  2020-5-14  2020-5-21  2020-5-28  \
# 0         45        435       1157      1547        685         93       1343
#
#    2020-6-4  2020-6-11  2020-6-18  ...  2021-11-30  2021-12-2  2021-12-7  \
# 0      1718       1998       2748  ...        3422       3922       3922
#
#    2021-12-9  2021-12-14  2021-12-16  2021-12-21  2021-12-23  2021-12-28  \
# 0       4482        4482        5982        5982        6282        6224
#
#    2021-12-30
# 0        7124
#
# [1 rows x 140 columns]

# %%
isnull = df.isnull().sum().sum()  #檢查缺失值
print("缺失值總數: ",isnull)
print(df.iloc[:,66:70])
print(df.isnull().iloc[:,66:70])

df = df.dropna(axis=1)  # 刪除有null的列
isnull = df.isnull().sum().sum()  #檢查缺失值
print("刪除後缺失值總數: ",isnull)
print(df.isnull().iloc[:,66:70])
# Out:
# 缺失值總數:  1
#    2021-4-15  2021-4-22  2021-4-27  2021-4-29
# 0       2563       3118        NaN       4618
#    2021-4-15  2021-4-22  2021-4-27  2021-4-29
# 0      False      False       True      False
# 刪除後缺失值總數:  0
#    2021-4-15  2021-4-22  2021-4-29  2021-5-4
# 0      False      False      False     False

# %%
daily_cases = df.sum(axis=0)  # 0:每一列的內容值互相相加 (列1+...+列n =列sum_下面);  1:每一行的內容值相加 (=行sum_右邊)
#print(daily_cases.values)
print("數據=\n",daily_cases.head())
print("日期=\n",daily_cases.index)

daily_cases.index = pd.to_datetime(daily_cases.index)  # column index(時間)的智慧轉換

print("日期(智慧轉換)=",daily_cases.index)
# Out:
# 數據=
#  2020-4-16      45
# 2020-4-23     435
# 2020-4-30    1157
# 2020-5-7     1547
# 2020-5-14     685
# dtype: int64
# 日期=
#  Index(['2020-4-16', '2020-4-23', '2020-4-30', '2020-5-7', '2020-5-14',
#        '2020-5-21', '2020-5-28', '2020-6-4', '2020-6-11', '2020-6-18',
#        ...
#        '2021-11-30', '2021-12-2', '2021-12-7', '2021-12-9', '2021-12-14',
#        '2021-12-16', '2021-12-21', '2021-12-23', '2021-12-28', '2021-12-30'],
#       dtype='object', length=139)
# 日期(智慧轉換)= DatetimeIndex(['2020-04-16', '2020-04-23', '2020-04-30', '2020-05-07',
#                '2020-05-14', '2020-05-21', '2020-05-28', '2020-06-04',
#                '2020-06-11', '2020-06-18',
#                ...
#                '2021-11-30', '2021-12-02', '2021-12-07', '2021-12-09',
#                '2021-12-14', '2021-12-16', '2021-12-21', '2021-12-23',
#                '2021-12-28', '2021-12-30'],
#               dtype='datetime64[ns]', length=139, freq=None)

# %%
x = daily_cases.index  # 取column index(2020-01)
y = daily_cases.values  # 取DataFrame的內容值
print(x)
print(y)
plt.figure(figsize=(10,6))
plt.title('In_Stock')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.plot(x, y)
plt.show()
# Out:
# DatetimeIndex(['2020-04-16', '2020-04-23', '2020-04-30', '2020-05-07',
#                '2020-05-14', '2020-05-21', '2020-05-28', '2020-06-04',
#                '2020-06-11', '2020-06-18',
#                ...
#                '2021-11-30', '2021-12-02', '2021-12-07', '2021-12-09',
#                '2021-12-14', '2021-12-16', '2021-12-21', '2021-12-23',
#                '2021-12-28', '2021-12-30'],
#               dtype='datetime64[ns]', length=139, freq=None)
# [   45   435  1157  1547   685    93  1343  1718  1998  2748  3498  4248
#   4248  3792  3792  3792  2702  2232  2232  1252  1012    92   122   762
#    252    -3   107   437  -478 -1248  -568  -353  -163   807   767  1587
#   1887  1392   465   465   465   625   625  1125  1255  2255  3255  3040
#   2715  2290  2290  3010  2065  2765  1550  2250  2250  2950  2950  3140
#   3140  2895  2508  2508  2508  2508  2563  3118  4618  4618  5368  4423
#   5123  4694  5394  5394  4504  4504  5504  5504  5630  5630  4685  4685
#   5485  5167  5967  5007  5039  5039  2846  2846  2701  2701  2179  2179
#   1469  1469   986   196     0     0   200  -745   255   255   110   110
#   2110  2110  3910  3910  5653  5293  4820  4820  4820  4820  4820  4820
#   3555  3555  2721  2721  3401  3401  3801  3801  4801  3422  3922  3922
#   4482  4482  5982  5982  6282  6224  7124]

# %% [raw]
# print("原本累加:")
# print(daily_cases.head())
#
# print("\n轉成每日數量:")
# temp = daily_cases.diff()  #預設是計算每一列做相減
# print(temp.head())
#
# print("\n填充NaN值後:")
# daily_cases = temp.fillna(value=daily_cases[0])
# print(daily_cases.head())
#
# print("\n轉int後:")
# daily_cases = daily_cases.astype(np.int64)  # 轉成int64
# print(daily_cases.head())
#
# print("\nShape: ",daily_cases.shape)

# %% [raw]
# x = daily_cases.index  # 取column index(2020-01)
# y = daily_cases.values  # 取DataFrame的內容值
#
# plt.figure(figsize=(8,6))
# plt.title('Daily cases')
# plt.xlabel("Date")
# plt.ylabel("Cases")
# plt.plot(x, y)
# plt.show()

# %% [markdown]
# ## 2_數據預處理

# %%
print("有", daily_cases.size,"天的數據")
val_data_size = 56  # 設定切多少天當驗證集
train_data = daily_cases[:-val_data_size]  # 取前面
val_data = daily_cases[train_data.size:]  # 取後面
print("\n訓練集",train_data.size,"天\n預測集",val_data.size,"天")

print("\ntrain_data=\n",train_data)
print("\nval_data=\n",val_data)
# Out:
# 有 139 天的數據
#
# 訓練集 83 天
# 預測集 56 天
#
# train_data=
#  2020-04-16      45
# 2020-04-23     435
# 2020-04-30    1157
# 2020-05-07    1547
# 2020-05-14     685
#               ...
# 2021-06-03    5504
# 2021-06-08    5504
# 2021-06-10    5630
# 2021-06-15    5630
# 2021-06-17    4685
# Length: 83, dtype: int64
#
# val_data=
#  2021-06-22    4685
# 2021-06-24    5485
# 2021-06-29    5167
# 2021-07-01    5967
# 2021-07-06    5007
# 2021-07-08    5039
# 2021-07-13    5039
# 2021-07-15    2846
# 2021-07-20    2846
# 2021-07-22    2701
# 2021-07-27    2701
# 2021-07-29    2179
# 2021-08-03    2179
# 2021-08-05    1469
# 2021-08-10    1469
# 2021-08-12     986
# 2021-08-17     196
# 2021-08-19       0
# 2021-08-24       0
# 2021-08-26     200
# 2021-08-31    -745
# 2021-09-02     255
# 2021-09-07     255
# 2021-09-09     110
# 2021-09-14     110
# 2021-09-16    2110
# 2021-09-21    2110
# 2021-09-23    3910
# 2021-09-28    3910
# 2021-09-30    5653
# 2021-10-05    5293
# 2021-10-07    4820
# 2021-10-12    4820
# 2021-10-14    4820
# 2021-10-19    4820
# 2021-10-21    4820
# 2021-10-26    4820
# 2021-10-28    3555
# 2021-11-02    3555
# 2021-11-04    2721
# 2021-11-09    2721
# 2021-11-11    3401
# 2021-11-16    3401
# 2021-11-18    3801
# 2021-11-23    3801
# 2021-11-25    4801
# 2021-11-30    3422
# 2021-12-02    3922
# 2021-12-07    3922
# 2021-12-09    4482
# 2021-12-14    4482
# 2021-12-16    5982
# 2021-12-21    5982
# 2021-12-23    6282
# 2021-12-28    6224
# 2021-12-30    7124
# dtype: int64

# %%
# 提高模型的"訓練速度"、"性能" ---> 按比例縮放數據(0~1)
# 使用scikit-learn的MinMaxScaler(最小最大值標準化)
# Reference: https://cloud.tencent.com/developer/article/1770568

# 注意: 是用train data進行擬合fit(模型)，然後對 train & val 都用此模型進行 trainsform (因fit兩次會造成在不同標準下做trainsform)
## train: fit + transform
## val: transform

# DataFrame(467行) -> values內容值(467列,1行)
train_data = np.expand_dims(train_data, axis=1)  # (467列，1列存放1個數值)
val_data = np.expand_dims(val_data, axis=1)    # axis=1: (467) -> (467,1)

print("轉換前:")
print(train_data[:5])

# 1. fit: (做完就包含數據分布情況，但未歸一化)
scaler_type = MinMaxScaler()  # 選擇計算類型
scaler = scaler_type.fit(train_data)  # 自動算出"最大值" "最小值"
#print(scaler.data_max_)  # 測試: 最大值


# 2. transform: (train)
print("train_data shape=", train_data.shape)
train_data = scaler.transform(train_data)  # 歸一化 (意思是，將數據壓縮到0-1之間，對應MinMax規範方法)
    # 歸一化可以消除量綱對最終結果的影響，使不同變數具有可比性。
    # 例子: 比如兩個人體重差10KG，身高差0.02M，在衡量兩個人的差別時體重的差距會把身高的差距完全掩蓋，歸一化之後就不會有這樣的問題。
    
print("\n轉換後:")
print(train_data[:5])

# 2. transform: (val)
# val_data = (243, 1)
val_data = scaler.transform(val_data)
# val_data = <class 'numpy.ndarray'>
# Out:
# 轉換前:
# [[  45]
#  [ 435]
#  [1157]
#  [1547]
#  [ 685]]
# train_data shape= (83, 1)
#
# 轉換後:
# [[0.18799069]
#  [0.24469322]
#  [0.3496656 ]
#  [0.40636813]
#  [0.281041  ]]

# %%
# 七天一個循環 (x:前7天  y_label:第8天)

print("train data=",len(train_data),"\n")
data = train_data

def create_sequence(data, seq_length):
    x_list = []
    y_list = []
    for i in range(len(data)-seq_length):  # !!重要: 不能-1，發現會導致少算一次，前面版本都錯了QQ
        x = data[i:i+seq_length]  # 0~6
        y = data[i+seq_length]  # 7
        x_list.append(x)
        y_list.append(y)  # !!注意: val_data中的第7天為y_list[0]的開頭
        
    return np.array(x_list), np.array(y_list)

seq_length = 5  # time_step

train_x, train_y = create_sequence(train_data, seq_length)
val_x, val_y = create_sequence(val_data, seq_length)

train_x = torch.from_numpy(train_x)
train_y = torch.from_numpy(train_y).float()
val_x = torch.from_numpy(val_x).float()
val_y = torch.from_numpy(val_y).float()

print("train x=",train_x.shape)
print("train y=",train_y.shape,"\n")
print(train_x[0],"\n")  # !!!原本數據類型: float64 -> 餵入model數據 要轉成 float32 才能run

train_x = train_x.float()  # float64 -> float32
print(train_x[0])
# Out:
# train data= 83
#
# train x= torch.Size([78, 5, 1])
# train y= torch.Size([78, 1])
#
# tensor([[0.1880],
#         [0.2447],
#         [0.3497],
#         [0.4064],
#         [0.2810]], dtype=torch.float64)
#
# tensor([[0.1880],
#         [0.2447],
#         [0.3497],
#         [0.4064],
#         [0.2810]])

# %% [markdown]
# ## 3_建立模型-LSTM

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout, seq_length):  # 這裡加入要傳入的參數，使用時記得要加self.X = X
        super(LSTM, self).__init__()
        
        # 導入參數
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.dropout = dropout
        self.seq_length = seq_length
        
        # model設計
        self.rnn = nn.LSTM(
            input_size = input_size,  # input shape
            hidden_size = hidden_size,  # output shape
            num_layers = num_layers,  # 有幾層LSTM
            #batch_first = True  # 只是做 原(459,7,1) -> (7,459,1)，這次沒有設batch_size，固batch_size=459 (全部data)
                                 # (batch_size, time_step, input_size) batch已經在最前面，不需再batch_first
        )
        #self.fc = nn.Linear(hidden_size, 1) # Linear input_feature = ()
        self.out = nn.Linear(hidden_size, 1)  # (in_features, out_features)->(512, 1)
        self.init_weights()
        
    def init_weights(self):
        initrange = 0.5
        self.out.weight.data.uniform_(-initrange, initrange)
        self.out.bias.data.zero_()
        
    def reset_hidden_state(self):  # 清空inputs的 h_0, c_0 (state)->讓每個epoch開始訓練 都是空的state
        self.h_0 = torch.zeros(self.num_layers, self.seq_length, self.hidden_size)  # 透過self，抓取外界傳入的參數(初始化需先導入)
        self.c_0 = torch.zeros(self.num_layers, self.seq_length, self.hidden_size)
        
    def forward(self, x):
        """
        x: (batch_size, time_step(seq_length), input_size)
        h_n = 最後一個time_step的 "hidden state" (輸出)   h_n = lstm_out[:,-1,:]
        c_n = 最後一個time_step的 "cell state" (cell當前狀態)
        """
        
        # 若有使用gpu，hidden tensor也需移到gpu
        if use_GPU == True and torch.cuda.is_available() == True:
            self.h_0, self.c_0 = self.h_0.cuda(), self.c_0.cuda()
            
        #---x: (459, 7, 1)    
        lstm_out, (self.h_n, self.c_n) = self.rnn(x, (self.h_0, self.c_0))  # 1 -> 512 
        #---lstm_out: (459, 7, 512)
        
        # 查看hidden_state (tuple → tensor)
        #hidden_state = torch.stack(list((self.h_0,self.c_0)), dim=0)  # h_n, c_n = hidden_state = (2, num_layers, 7, 512)
        #print(hidden_state.shape)  # hidden_state: ( (h,c), num_layers, time_step(seq_length), hidden_size)
        
        #---lstm_out: (459, 7, 512)
        last_time_step = lstm_out[:,-1,:] 
        output = self.out(last_time_step)
        return output
        
        """ 原本失敗寫法
        last_time_step = lstm_out.view(seq_length, len(x), hidden_size)  # 改變數據shape (取出 7的最後一個 時間步(time_step) 的輸出)
        #---last_time_step: (7, 459, 512)
        last_time_step = last_time_step[-1]  # 取0~6的最後一列
        #---last_time_step: (459, 512) 
        output = self.out(last_time_step)  # (459, 512) -> (459, 1)
        #---output: (459, 1)  # 459列 預測的結果
        return output  # y_predict
        """
        """
        #print("lstm_out=", lstm_out.shape)
        print("bbbb=",flatten_output.shape)
        flatten_output = lstm_out[:, -1].view(-1, self.hidden_size) 
        print("after_shape=", flatten_output[0][0])
        #print("flatten_output=", flatten_output.shape)
        return self.fc(flatten_output)
        """

# %% [raw]
# # linear分類器-小例子
# np.random.seed(42)  # 強迫固定亂數，方便研究
# torch.manual_seed(42)
# x = torch.randn(4,2,1)
# print(x.shape)
#
# x = x.view(8,-1)  #展平成n列1行
# print(x.shape)
# print(x)

# %% [markdown]
# [lstm_out、h_n 和 c_n 之間的關係](https://blog.csdn.net/sdnuwjw/article/details/111221937)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4.1_訓練模型
# - 回歸模型評估指標 [[總覽1](https://www.cnblogs.com/HuZihu/p/10300760.html)] [[總覽2](https://blog.csdn.net/lch551218/article/details/113573931)]
#     - [R squared](https://medium.com/qiubingcheng/%E5%9B%9E%E6%AD%B8%E5%88%86%E6%9E%90-regression-analysis-%E7%9A%84r%E5%B9%B3%E6%96%B9-r-squared-%E8%88%87%E8%AA%BF%E6%95%B4%E5%BE%8Cr%E5%B9%B3%E6%96%B9-adjusted-r-squared-f38ad733bc4e) ([2](https://blog.csdn.net/jpld/article/details/103526882?utm_medium=distribute.pc_relevant.none-task-blog-2~default~baidujs_baidulandingword~default-0-103526882-blog-80061191.pc_relevant_default&spm=1001.2101.3001.4242.1&utm_relevant_index=2)) ([3](https://blog.csdn.net/jpld/article/details/103526882?utm_medium=distribute.pc_relevant.none-task-blog-2~default~baidujs_baidulandingword~default-0-103526882-blog-80061191.pc_relevant_default&spm=1001.2101.3001.4242.1&utm_relevant_index=2)) ([判斷標準](http://amebse.nchu.edu.tw/new_page_535.htm))

# %%
def train_model(model, epoch, lr, train_data, train_label, val_data, val_label, use_GPU, performance_eval):
    # 設定loss模型 + 優化器
    loss_fn = torch.nn.MSELoss(reduction='sum')  # 默認'mean'
    optim = torch.optim.Adam(params=model.parameters(), lr=lr)
    # 動態調整學習率
    #lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optim, mode='min', factor=0.1, patience=100, min_lr=0.00001)
    
    # 回歸模型的表現評價指標（Regression Model Performance Evaluation Metric）
    best_epoch = 0
    if performance_eval == 'MAE':  # https://pytorch.org/docs/stable/generated/torch.nn.L1Loss.html#torch.nn.L1Loss
        evaluation_func = torch.nn.L1Loss(reduction='mean')  # (平均絕對誤差) MAE = sum(|y-x|)的平均
        best_evaluation = 1.0  # 初始最高，越低越好
    elif performance_eval == 'MSE':  # https://pytorch.org/docs/stable/generated/torch.nn.MSELoss.html#torch.nn.MSELoss
        evaluation_func = torch.nn.MSELoss(reduction='mean')  # (均方誤差) MSE = sum((y-x)^2)的平均
        best_evaluation = 1.0  # 初始最高，越低越好
    elif performance_eval == 'R_square':  # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html
        evaluation_func = torch.nn.MSELoss(reduction='sum')
        best_evaluation = -10.0  # 初始最低，越高越好
    elif performance_eval == 'MAPE':
        evaluation_func = None
        best_evaluation = 100.0  # 初始最高，越低越好  # https://stats.stackexchange.com/questions/58391/mean-absolute-percentage-error-mape-in-scikit-learn
        

    # 保存loss歷史數據，plt看圖用
    train_loss_list = np.zeros(epoch)
    val_loss_list = np.zeros(epoch)

    # 數據轉移到GPU運算
    if use_GPU == True and torch.cuda.is_available() == True:
        model.cuda()  # model參數計算 -> 移到GPU
        train_data, train_label = train_data.cuda(), train_label.cuda()
        if val_data is not None:
            val_data, val_label = val_data.cuda(), val_label.cuda()
        

    
    # 開始訓練epoch
    for i in range(epoch):
        model.train()  # 開啟訓練模式 (因驗證時會改成eval模式)
        model.reset_hidden_state()  # 無狀態LSTM
        
        #---train_data: (459, 7, 1)
        y_pred = model(train_data)
        #---y_pred: (459, 1)
                
        # 比較data差異
        #print(train_label[5])
        #print(y_pred[5])
        
        # 計算loss
        loss = loss_fn(train_label, y_pred)  # (y_predict, y_label)
        
        # 加入測試集-驗證+評估最佳模型
        if val_data is not None:
            with torch.no_grad():  # 被該語句包裹起來的程式碼，就不會被追蹤gradient
                y_pred_val = model(val_data)
                loss_val = loss_fn(val_label, y_pred_val)
                
                # 使用val_data評估回歸模型表現的指標----------------------------------
                if performance_eval == 'MAE' or performance_eval == 'MSE':
                    evaluation = evaluation_func(val_label, y_pred_val)  # 導入模型評估指標
                    if best_evaluation > evaluation.item():
                        best_evaluation = evaluation.item()  # 最佳模型評估指標
                        best_epoch = i
                        # 保存模型
                        torch.save(model,'best_model.pth')  # 根據評估指標-保存最佳模型
                elif performance_eval == 'R_square':
                    # 手刻R_square:
                    # R_square = 1 - {sum((y-x)^2) / sum((y-y平均)^2)}
                    evaluation = evaluation_func(val_label, y_pred_val)
                    evaluation = evaluation.item() / np.sum( np.square( val_label.cpu().numpy() - np.mean(val_label.cpu().numpy()) ) )
                    evaluation = 1 - evaluation
                    #evaluation = r2_score(val_label.cpu(), y_pred_val.cpu())  # 利用sklearn，快速導入R_square評估指標
                    if best_evaluation < evaluation:
                        best_evaluation = evaluation
                        best_epoch = i
                        # 保存模型
                        torch.save(model,'best_model.pth')
                elif performance_eval == 'MAPE':
                    # 手刻MAPE:
                    evaluation = np.mean(np.abs(val_label.cpu().numpy() - y_pred_val.cpu().numpy()) / np.abs(val_label.cpu().numpy()))*100
                    if best_evaluation > evaluation:
                        best_evaluation = evaluation
                        best_epoch = i
                        # 保存模型
                        torch.save(model,'best_model.pth')
                                   
                if i == (epoch-1):
                    torch.save(model,'last_model.pth')  # 根據最後一回合-保存模型
                #-------------------------------------------------------
                
            val_loss_list[i] = loss_val.item()  # 保存loss_val history
            
            # 每十回合印出那一個回合的loss值(非最佳)，"評估最佳指標"才是每回合的(最佳)
            if (i%20 == 0) or (i == epoch-1):  # 最後一個epoch也印出
                print(f'Epoch {i}  train loss: {loss.item():.4f}  val loss: {loss_val.item():.4f}    最佳評估指標 {performance_eval}= {best_evaluation:.4f}  (best_epoch={best_epoch})')  # :.4f 取小數後四位
            #if i == best_epoch:
                #print(f'    best_epoch {best_epoch}  val loss: {loss_val.item():.4f}')
        
        elif (i%20 == 0) or (i == epoch-1):  # 沒有val_data時
            print(f'Epoch {i}  train loss: {loss.item()}')  # .item(): tensor->內容值(values)
        
        train_loss_list[i] = loss.item()  # 保存loss history

        # 動態調整學習率
        #lr_scheduler.step(best_evaluation)
        
        # 固定不變
        optim.zero_grad()
        loss.backward()
        optim.step()

    return model.eval(), train_loss_list, val_loss_list  # model.eval() 因後面是測試模式

# %% [markdown]
# ## 4.2_訓練模型-設定超參數

# %%
# 設定參數--------------------------------------------------------------------
epoch = 3000
lr = 1e-3
input_size = 1  # 若為圖片，size= W x H，這裡是確診人數，size= 1
hidden_size = 5  # 隱藏層神經元數
num_layers = 1  # LSTM層數
dropout = 0.5
seq_length = 5  # 就是time_step; 若要調值，上面 "2.數據預處理-seq_length" 也要改
use_GPU = True
performance_eval = 'MSE'  # 模型評估指標: MSE、MAE、R_square、MAPE

# 強迫固定亂數，方便研究用
np.random.seed(1)
torch.manual_seed(1)
# ---------------------------------------------------------------------------

# 讀取model
model = LSTM(input_size, hidden_size, num_layers, dropout, seq_length)  # Model: 跑了__init__初始化的東西

# 查看GPU訊息
if use_GPU == True:
    if torch.cuda.is_available() == True:
        GPU_num = torch.cuda.device_count()
        print(f'GPU總共有 {GPU_num} 個')
        print(f'顯示卡: {torch.cuda.get_device_name(0)}\n')  # 0: 第0張顯示卡
        os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # 如果GPU0正在運行程序，需要指定其他GPU時使用 (需 import os)
    else:
        print(f'我沒有GPU')
        
# 查看餵入的數據shape是否正確
print("查看餵入的數據shape是否正確:")
print("x =",train_x.shape, "  (batch_size, time_step, input_size)\n")


# 開始訓練
model, train_loss_list, val_loss_list = train_model(model, epoch, lr, train_x, train_y, val_x, val_y, use_GPU, performance_eval) 
# Model: 跑了forward的東西
# 這裡的model = .eval()測試模式
# Out:
# GPU總共有 1 個
# 顯示卡: NVIDIA GeForce RTX 3060
#
# 查看餵入的數據shape是否正確:
# x = torch.Size([78, 5, 1])   (batch_size, time_step, input_size)
#
# Epoch 0  train loss: 35.9837  val loss: 32.9824    最佳評估指標 MSE= 0.6467  (best_epoch=0)
# Epoch 20  train loss: 27.5016  val loss: 26.2394    最佳評估指標 MSE= 0.5145  (best_epoch=20)
# Epoch 40  train loss: 20.1997  val loss: 20.2668    最佳評估指標 MSE= 0.3974  (best_epoch=40)
# Epoch 60  train loss: 13.5338  val loss: 14.5659    最佳評估指標 MSE= 0.2856  (best_epoch=60)
# Epoch 80  train loss: 7.7735  val loss: 9.2681    最佳評估指標 MSE= 0.1817  (best_epoch=80)
# Epoch 100  train loss: 4.6339  val loss: 5.8066    最佳評估指標 MSE= 0.1139  (best_epoch=100)
# Epoch 120  train loss: 4.0120  val loss: 4.5864    最佳評估指標 MSE= 0.0899  (best_epoch=120)
# Epoch 140  train loss: 3.9224  val loss: 4.3533    最佳評估指標 MSE= 0.0854  (best_epoch=140)
# Epoch 160  train loss: 3.8140  val loss: 4.3213    最佳評估指標 MSE= 0.0847  (best_epoch=160)
# Epoch 180  train loss: 3.7083  val loss: 4.2497    最佳評估指標 MSE= 0.0833  (best_epoch=180)
# Epoch 200  train loss: 3.5992  val loss: 4.1366    最佳評估指標 MSE= 0.0811  (best_epoch=200)
# Epoch 220  train loss: 3.4847  val loss: 4.0197    最佳評估指標 MSE= 0.0788  (best_epoch=220)
# Epoch 240  train loss: 3.3649  val loss: 3.9051    最佳評估指標 MSE= 0.0766  (best_epoch=240)
# Epoch 260  train loss: 3.2401  val loss: 3.7841    最佳評估指標 MSE= 0.0742  (best_epoch=260)
# Epoch 280  train loss: 3.1099  val loss: 3.6584    最佳評估指標 MSE= 0.0717  (best_epoch=280)
# Epoch 300  train loss: 2.9747  val loss: 3.5304    最佳評估指標 MSE= 0.0692  (best_epoch=300)
# Epoch 320  train loss: 2.8329  val loss: 3.3943    最佳評估指標 MSE= 0.0666  (best_epoch=320)
# Epoch 340  train loss: 2.6885  val loss: 3.2598    最佳評估指標 MSE= 0.0639  (best_epoch=340)
# Epoch 360  train loss: 2.5417  val loss: 3.1244    最佳評估指標 MSE= 0.0613  (best_epoch=360)
# Epoch 380  train loss: 2.3957  val loss: 2.9905    最佳評估指標 MSE= 0.0586  (best_epoch=380)
# Epoch 400  train loss: 2.2547  val loss: 2.8619    最佳評估指標 MSE= 0.0561  (best_epoch=400)
# Epoch 420  train loss: 2.1268  val loss: 2.7487    最佳評估指標 MSE= 0.0539  (best_epoch=420)
# Epoch 440  train loss: 2.0140  val loss: 2.6491    最佳評估指標 MSE= 0.0519  (best_epoch=440)
# Epoch 460  train loss: 1.9189  val loss: 2.5674    最佳評估指標 MSE= 0.0503  (best_epoch=460)
# Epoch 480  train loss: 1.8393  val loss: 2.4991    最佳評估指標 MSE= 0.0490  (best_epoch=480)
# Epoch 500  train loss: 1.7722  val loss: 2.4383    最佳評估指標 MSE= 0.0478  (best_epoch=500)
# Epoch 520  train loss: 1.7122  val loss: 2.3835    最佳評估指標 MSE= 0.0467  (best_epoch=520)
# Epoch 540  train loss: 1.6569  val loss: 2.3290    最佳評估指標 MSE= 0.0457  (best_epoch=540)
# Epoch 560  train loss: 1.6048  val loss: 2.2754    最佳評估指標 MSE= 0.0446  (best_epoch=560)
# Epoch 580  train loss: 1.5548  val loss: 2.2226    最佳評估指標 MSE= 0.0436  (best_epoch=580)
# Epoch 600  train loss: 1.5066  val loss: 2.1710    最佳評估指標 MSE= 0.0426  (best_epoch=600)
# Epoch 620  train loss: 1.4597  val loss: 2.1194    最佳評估指標 MSE= 0.0416  (best_epoch=620)
# Epoch 640  train loss: 1.4148  val loss: 2.0700    最佳評估指標 MSE= 0.0406  (best_epoch=640)
# Epoch 660  train loss: 1.3710  val loss: 2.0213    最佳評估指標 MSE= 0.0396  (best_epoch=660)
# Epoch 680  train loss: 1.3273  val loss: 1.9729    最佳評估指標 MSE= 0.0387  (best_epoch=680)
# Epoch 700  train loss: 1.2864  val loss: 1.9261    最佳評估指標 MSE= 0.0378  (best_epoch=700)
# Epoch 720  train loss: 1.2465  val loss: 1.8810    最佳評估指標 MSE= 0.0369  (best_epoch=720)
# Epoch 740  train loss: 1.2082  val loss: 1.8374    最佳評估指標 MSE= 0.0360  (best_epoch=740)
# Epoch 760  train loss: 1.1708  val loss: 1.7947    最佳評估指標 MSE= 0.0352  (best_epoch=760)
# Epoch 780  train loss: 1.1357  val loss: 1.7541    最佳評估指標 MSE= 0.0344  (best_epoch=780)
# Epoch 800  train loss: 1.1021  val loss: 1.7146    最佳評估指標 MSE= 0.0336  (best_epoch=800)
# Epoch 820  train loss: 1.0693  val loss: 1.6763    最佳評估指標 MSE= 0.0329  (best_epoch=820)
# Epoch 840  train loss: 1.0390  val loss: 1.6407    最佳評估指標 MSE= 0.0322  (best_epoch=840)
# Epoch 860  train loss: 1.0108  val loss: 1.6078    最佳評估指標 MSE= 0.0315  (best_epoch=860)
# Epoch 880  train loss: 0.9841  val loss: 1.5757    最佳評估指標 MSE= 0.0309  (best_epoch=880)
# Epoch 900  train loss: 0.9586  val loss: 1.5458    最佳評估指標 MSE= 0.0303  (best_epoch=900)
# Epoch 920  train loss: 0.9362  val loss: 1.5183    最佳評估指標 MSE= 0.0298  (best_epoch=920)
# Epoch 940  train loss: 0.9148  val loss: 1.4927    最佳評估指標 MSE= 0.0293  (best_epoch=940)
# Epoch 960  train loss: 0.8956  val loss: 1.4683    最佳評估指標 MSE= 0.0288  (best_epoch=960)
# Epoch 980  train loss: 0.8787  val loss: 1.4468    最佳評估指標 MSE= 0.0284  (best_epoch=980)
# Epoch 1000  train loss: 0.8623  val loss: 1.4264    最佳評估指標 MSE= 0.0280  (best_epoch=1000)
# Epoch 1020  train loss: 0.8479  val loss: 1.4074    最佳評估指標 MSE= 0.0276  (best_epoch=1020)
# Epoch 1040  train loss: 0.8348  val loss: 1.3889    最佳評估指標 MSE= 0.0272  (best_epoch=1040)
# Epoch 1060  train loss: 0.8228  val loss: 1.3720    最佳評估指標 MSE= 0.0269  (best_epoch=1060)
# Epoch 1080  train loss: 0.8118  val loss: 1.3559    最佳評估指標 MSE= 0.0266  (best_epoch=1080)
# Epoch 1100  train loss: 0.8015  val loss: 1.3401    最佳評估指標 MSE= 0.0263  (best_epoch=1100)
# Epoch 1120  train loss: 0.7921  val loss: 1.3249    最佳評估指標 MSE= 0.0260  (best_epoch=1120)
# Epoch 1140  train loss: 0.7830  val loss: 1.3098    最佳評估指標 MSE= 0.0257  (best_epoch=1140)
# Epoch 1160  train loss: 0.7741  val loss: 1.2954    最佳評估指標 MSE= 0.0254  (best_epoch=1160)
# Epoch 1180  train loss: 0.7662  val loss: 1.2810    最佳評估指標 MSE= 0.0251  (best_epoch=1180)
# Epoch 1200  train loss: 0.7578  val loss: 1.2668    最佳評估指標 MSE= 0.0248  (best_epoch=1200)
# Epoch 1220  train loss: 0.7506  val loss: 1.2528    最佳評估指標 MSE= 0.0246  (best_epoch=1220)
# Epoch 1240  train loss: 0.7433  val loss: 1.2397    最佳評估指標 MSE= 0.0243  (best_epoch=1240)
# Epoch 1260  train loss: 0.7361  val loss: 1.2262    最佳評估指標 MSE= 0.0240  (best_epoch=1260)
# Epoch 1280  train loss: 0.7297  val loss: 1.2129    最佳評估指標 MSE= 0.0238  (best_epoch=1280)
# Epoch 1300  train loss: 0.7229  val loss: 1.2001    最佳評估指標 MSE= 0.0235  (best_epoch=1300)
# Epoch 1320  train loss: 0.7165  val loss: 1.1871    最佳評估指標 MSE= 0.0233  (best_epoch=1320)
# Epoch 1340  train loss: 0.7102  val loss: 1.1752    最佳評估指標 MSE= 0.0230  (best_epoch=1340)
# Epoch 1360  train loss: 0.7042  val loss: 1.1633    最佳評估指標 MSE= 0.0228  (best_epoch=1360)
# Epoch 1380  train loss: 0.6981  val loss: 1.1516    最佳評估指標 MSE= 0.0226  (best_epoch=1380)
# Epoch 1400  train loss: 0.6924  val loss: 1.1402    最佳評估指標 MSE= 0.0224  (best_epoch=1400)
# Epoch 1420  train loss: 0.6869  val loss: 1.1287    最佳評估指標 MSE= 0.0221  (best_epoch=1420)
# Epoch 1440  train loss: 0.6814  val loss: 1.1179    最佳評估指標 MSE= 0.0219  (best_epoch=1440)
# Epoch 1460  train loss: 0.6763  val loss: 1.1073    最佳評估指標 MSE= 0.0217  (best_epoch=1460)
# Epoch 1480  train loss: 0.6711  val loss: 1.0960    最佳評估指標 MSE= 0.0215  (best_epoch=1480)
# Epoch 1500  train loss: 0.6661  val loss: 1.0863    最佳評估指標 MSE= 0.0213  (best_epoch=1500)
# Epoch 1520  train loss: 0.6613  val loss: 1.0763    最佳評估指標 MSE= 0.0211  (best_epoch=1520)
# Epoch 1540  train loss: 0.6567  val loss: 1.0664    最佳評估指標 MSE= 0.0209  (best_epoch=1540)
# Epoch 1560  train loss: 0.6519  val loss: 1.0570    最佳評估指標 MSE= 0.0207  (best_epoch=1560)
# Epoch 1580  train loss: 0.6477  val loss: 1.0473    最佳評估指標 MSE= 0.0205  (best_epoch=1580)
# Epoch 1600  train loss: 0.6433  val loss: 1.0389    最佳評估指標 MSE= 0.0204  (best_epoch=1600)
# Epoch 1620  train loss: 0.6394  val loss: 1.0303    最佳評估指標 MSE= 0.0202  (best_epoch=1620)
# Epoch 1640  train loss: 0.6352  val loss: 1.0212    最佳評估指標 MSE= 0.0200  (best_epoch=1640)
# Epoch 1660  train loss: 0.6312  val loss: 1.0129    最佳評估指標 MSE= 0.0199  (best_epoch=1660)
# Epoch 1680  train loss: 0.6277  val loss: 1.0048    最佳評估指標 MSE= 0.0197  (best_epoch=1680)
# Epoch 1700  train loss: 0.6239  val loss: 0.9966    最佳評估指標 MSE= 0.0195  (best_epoch=1700)
# Epoch 1720  train loss: 0.6203  val loss: 0.9892    最佳評估指標 MSE= 0.0194  (best_epoch=1720)
# Epoch 1740  train loss: 0.6168  val loss: 0.9817    最佳評估指標 MSE= 0.0192  (best_epoch=1740)
# Epoch 1760  train loss: 0.6134  val loss: 0.9741    最佳評估指標 MSE= 0.0191  (best_epoch=1760)
# Epoch 1780  train loss: 0.6102  val loss: 0.9667    最佳評估指標 MSE= 0.0190  (best_epoch=1780)
# Epoch 1800  train loss: 0.6074  val loss: 0.9599    最佳評估指標 MSE= 0.0188  (best_epoch=1800)
# Epoch 1820  train loss: 0.6042  val loss: 0.9534    最佳評估指標 MSE= 0.0187  (best_epoch=1820)
# Epoch 1840  train loss: 0.6010  val loss: 0.9467    最佳評估指標 MSE= 0.0186  (best_epoch=1840)
# Epoch 1860  train loss: 0.5985  val loss: 0.9400    最佳評估指標 MSE= 0.0184  (best_epoch=1860)
# Epoch 1880  train loss: 0.5953  val loss: 0.9335    最佳評估指標 MSE= 0.0183  (best_epoch=1880)
# Epoch 1900  train loss: 0.5931  val loss: 0.9271    最佳評估指標 MSE= 0.0182  (best_epoch=1900)
# Epoch 1920  train loss: 0.5902  val loss: 0.9214    最佳評估指標 MSE= 0.0181  (best_epoch=1920)
# Epoch 1940  train loss: 0.5879  val loss: 0.9153    最佳評估指標 MSE= 0.0179  (best_epoch=1940)
# Epoch 1960  train loss: 0.5855  val loss: 0.9096    最佳評估指標 MSE= 0.0178  (best_epoch=1959)
# Epoch 1980  train loss: 0.5833  val loss: 0.9037    最佳評估指標 MSE= 0.0177  (best_epoch=1979)
# Epoch 2000  train loss: 0.5812  val loss: 0.8980    最佳評估指標 MSE= 0.0176  (best_epoch=1999)
# Epoch 2020  train loss: 0.5789  val loss: 0.8926    最佳評估指標 MSE= 0.0175  (best_epoch=2019)
# Epoch 2040  train loss: 0.5767  val loss: 0.8876    最佳評估指標 MSE= 0.0174  (best_epoch=2040)
# Epoch 2060  train loss: 0.5745  val loss: 0.8821    最佳評估指標 MSE= 0.0173  (best_epoch=2060)
# Epoch 2080  train loss: 0.5725  val loss: 0.8771    最佳評估指標 MSE= 0.0172  (best_epoch=2080)
# Epoch 2100  train loss: 0.5708  val loss: 0.8724    最佳評估指標 MSE= 0.0171  (best_epoch=2099)
# Epoch 2120  train loss: 0.5689  val loss: 0.8674    最佳評估指標 MSE= 0.0170  (best_epoch=2120)
# Epoch 2140  train loss: 0.5671  val loss: 0.8621    最佳評估指標 MSE= 0.0169  (best_epoch=2140)
# Epoch 2160  train loss: 0.5655  val loss: 0.8579    最佳評估指標 MSE= 0.0168  (best_epoch=2160)
# Epoch 2180  train loss: 0.5639  val loss: 0.8537    最佳評估指標 MSE= 0.0167  (best_epoch=2179)
# Epoch 2200  train loss: 0.5627  val loss: 0.8484    最佳評估指標 MSE= 0.0166  (best_epoch=2200)
# Epoch 2220  train loss: 0.5609  val loss: 0.8442    最佳評估指標 MSE= 0.0166  (best_epoch=2218)
# Epoch 2240  train loss: 0.5593  val loss: 0.8398    最佳評估指標 MSE= 0.0165  (best_epoch=2240)
# Epoch 2260  train loss: 0.5578  val loss: 0.8357    最佳評估指標 MSE= 0.0164  (best_epoch=2260)
# Epoch 2280  train loss: 0.5564  val loss: 0.8312    最佳評估指標 MSE= 0.0163  (best_epoch=2280)
# Epoch 2300  train loss: 0.5548  val loss: 0.8275    最佳評估指標 MSE= 0.0162  (best_epoch=2299)
# Epoch 2320  train loss: 0.5536  val loss: 0.8235    最佳評估指標 MSE= 0.0161  (best_epoch=2320)
# Epoch 2340  train loss: 0.5525  val loss: 0.8191    最佳評估指標 MSE= 0.0161  (best_epoch=2340)
# Epoch 2360  train loss: 0.5511  val loss: 0.8154    最佳評估指標 MSE= 0.0160  (best_epoch=2360)
# Epoch 2380  train loss: 0.5499  val loss: 0.8116    最佳評估指標 MSE= 0.0159  (best_epoch=2380)
# Epoch 2400  train loss: 0.5487  val loss: 0.8082    最佳評估指標 MSE= 0.0158  (best_epoch=2400)
# Epoch 2420  train loss: 0.5474  val loss: 0.8047    最佳評估指標 MSE= 0.0158  (best_epoch=2419)
# Epoch 2440  train loss: 0.5464  val loss: 0.8014    最佳評估指標 MSE= 0.0157  (best_epoch=2439)
# Epoch 2460  train loss: 0.5452  val loss: 0.7979    最佳評估指標 MSE= 0.0156  (best_epoch=2460)
# Epoch 2480  train loss: 0.5442  val loss: 0.7939    最佳評估指標 MSE= 0.0156  (best_epoch=2480)
# Epoch 2500  train loss: 0.5431  val loss: 0.7912    最佳評估指標 MSE= 0.0155  (best_epoch=2499)
# Epoch 2520  train loss: 0.5421  val loss: 0.7879    最佳評估指標 MSE= 0.0154  (best_epoch=2520)
# Epoch 2540  train loss: 0.5412  val loss: 0.7842    最佳評估指標 MSE= 0.0154  (best_epoch=2540)
# Epoch 2560  train loss: 0.5405  val loss: 0.7810    最佳評估指標 MSE= 0.0153  (best_epoch=2560)
# Epoch 2580  train loss: 0.5396  val loss: 0.7783    最佳評估指標 MSE= 0.0153  (best_epoch=2580)
# Epoch 2600  train loss: 0.5383  val loss: 0.7752    最佳評估指標 MSE= 0.0152  (best_epoch=2600)
# Epoch 2620  train loss: 0.5378  val loss: 0.7723    最佳評估指標 MSE= 0.0151  (best_epoch=2619)
# Epoch 2640  train loss: 0.5368  val loss: 0.7693    最佳評估指標 MSE= 0.0151  (best_epoch=2640)
# Epoch 2660  train loss: 0.5359  val loss: 0.7666    最佳評估指標 MSE= 0.0150  (best_epoch=2660)
# Epoch 2680  train loss: 0.5352  val loss: 0.7636    最佳評估指標 MSE= 0.0150  (best_epoch=2680)
# Epoch 2700  train loss: 0.5346  val loss: 0.7613    最佳評估指標 MSE= 0.0149  (best_epoch=2699)
# Epoch 2720  train loss: 0.5335  val loss: 0.7587    最佳評估指標 MSE= 0.0149  (best_epoch=2719)
# Epoch 2740  train loss: 0.5331  val loss: 0.7560    最佳評估指標 MSE= 0.0148  (best_epoch=2740)
# Epoch 2760  train loss: 0.5323  val loss: 0.7535    最佳評估指標 MSE= 0.0148  (best_epoch=2760)
# Epoch 2780  train loss: 0.5314  val loss: 0.7509    最佳評估指標 MSE= 0.0147  (best_epoch=2780)
# Epoch 2800  train loss: 0.5310  val loss: 0.7489    最佳評估指標 MSE= 0.0147  (best_epoch=2799)
# Epoch 2820  train loss: 0.5304  val loss: 0.7460    最佳評估指標 MSE= 0.0146  (best_epoch=2820)
# Epoch 2840  train loss: 0.5299  val loss: 0.7444    最佳評估指標 MSE= 0.0146  (best_epoch=2838)
# Epoch 2860  train loss: 0.5292  val loss: 0.7422    最佳評估指標 MSE= 0.0146  (best_epoch=2860)
# Epoch 2880  train loss: 0.5285  val loss: 0.7399    最佳評估指標 MSE= 0.0145  (best_epoch=2878)
# Epoch 2900  train loss: 0.5280  val loss: 0.7374    最佳評估指標 MSE= 0.0145  (best_epoch=2899)
# Epoch 2920  train loss: 0.5274  val loss: 0.7357    最佳評估指標 MSE= 0.0144  (best_epoch=2920)
# Epoch 2940  train loss: 0.5268  val loss: 0.7334    最佳評估指標 MSE= 0.0144  (best_epoch=2939)
# Epoch 2960  train loss: 0.5265  val loss: 0.7314    最佳評估指標 MSE= 0.0143  (best_epoch=2960)
# Epoch 2980  train loss: 0.5258  val loss: 0.7297    最佳評估指標 MSE= 0.0143  (best_epoch=2979)
# Epoch 2999  train loss: 0.5253  val loss: 0.7279    最佳評估指標 MSE= 0.0143  (best_epoch=2999)

# %%
plt.plot(train_loss_list, label='Train loss')
plt.plot(val_loss_list, label='Val loss')
plt.title('Daily cases')
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE_sum)")
plt.ylim((0, 30))
plt.legend()

# %% [markdown]
# ## 5.1_最佳模型->預測未來幾天庫存量
# ### (利用預測的值來預測未來)

# %%
# 加載模型
best_model = torch.load('best_model.pth')

if use_GPU == True and torch.cuda.is_available() == True:
    best_model.cuda()
best_model.eval()  # 固定dropout和批次歸一化

with torch.no_grad():
    val_x = val_x.cuda()  # 轉回gpu
    # val_x = (235, 7, 1)
    val_seq_input = val_x[:1]
    # val_seq_input = (1, 7, 1)
    get_preds = []  # 存放model預測結果"get"
    
    # 把input前7天 + 透過模型預測的第8天 "串接起來" -> {右移一天} -> 此時input中上次預測的變第7天 + model -> 得到預測的第8天
    # -> {迴圈下去} -> 使用預測值作為預測未來幾天的輸入
    for _ in range(len(val_x)):
        # val_seq_input = (1, 7, 1)
        val_seq_pred = best_model(val_seq_input.cuda())
        # val_seq_pred = (1, 1)
        #print(val_seq_pred)
        get = torch.flatten(val_seq_pred).item()  # get = 取出model預測的"內容值"
        get_preds.append(get)  # 預測結果"串接起來"
        new_seq = val_seq_input.cpu().numpy().flatten()  # shape = (7)
        new_seq = np.append(new_seq, [get])  # shape = (8)
        new_seq = new_seq[1:]  # 向右移一天
        #print(new_seq)
        val_seq_input = torch.as_tensor(new_seq).view(1, seq_length, 1).float()  # torch.Size([7]) -> torch.Size([1, 7, 1])
        # val_seq_input = (1, 7, 1)

# %%
# 1. 撤銷val數據的normalize轉換比例 -> 逆縮放轉換 -> 得到原始數據"全球確診人數"
# 2. val_y(真實) vs. get_preds(模型預測)

#--------------------val_y(真實)---------------------
# val_y = (235, 1)
temp = np.expand_dims(val_y.flatten().numpy(), axis=0)  # 新增一維度 -> 0=[1, *, *], 1=[*, 1, *]
# temp = (1, 235)
#-----------------------------------
# transform: (len(), 1)
# inverse_transform: (1, len())
#-----------------------------------
# temp = (1, 235)
true_cases = scaler.inverse_transform(temp)  # inverse_transform
# true_cases = (1, 235)
true_cases = true_cases.flatten()
# true_case = (235)

#--------------------get_preds(模型預測)---------------------
# 做一樣的事
pred_cases = scaler.inverse_transform(np.expand_dims(get_preds, axis=0)).flatten()
print(pred_cases.shape)
# Out:
# (51,)

# %%
# 測試下來，不用轉shape，也可以 (對應前面"轉換前")
print(train_data[:5])
a = scaler.inverse_transform(train_data).flatten()
b = scaler.inverse_transform(np.expand_dims(train_data.flatten(), axis=0)).flatten()
print(a[:5])
print(b[:5])
# Out:
# [[0.18799069]
#  [0.24469322]
#  [0.3496656 ]
#  [0.40636813]
#  [0.281041  ]]
# [  45.  435. 1157. 1547.  685.]
# [  45.  435. 1157. 1547.  685.]

# %%
# plt.plot(x, y, label='')  (x=日期, y=全球確診人數) (必須len(x)=len(y)對應)
print("train_data = ",len(train_data))
print("val_data = ",len(val_data))
print("true_cases ( 起始值為val_data[7] ) = ",len(true_cases))
# 這裡要+7是因為true_cases的起始值為val_data[7]，create_sequence func()計算方式的關係

# plt.plot(x, y, label='')  (x=日期, y=全球確診人數) (必須len(x)=len(y)對應)
plt.figure(figsize=(8,6))
plt.plot(daily_cases.index[:len(train_data)], scaler.inverse_transform(train_data).flatten(), label='Historical Daily Cases')  #已知確診人數
plt.plot(daily_cases.index[len(train_data): len(train_data)+len(true_cases)], true_cases, label='Real Daily Cases')  # 預測之label
plt.plot(daily_cases.index[len(train_data): len(train_data)+len(pred_cases)], pred_cases, label='Predicted Daily Cases')  # 預測之Output
plt.title('Daily cases')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend()
# Out:
# train_data =  83
# val_data =  56
# true_cases ( 起始值為val_data[7] ) =  51

# %% [markdown]
# ## 5.2_最佳模型->預測未來幾天庫存量
# ### (每次預測的結果，去比較與真實的差異)

# %%
# 加載模型
best_model = torch.load('best_model.pth')
best_model.eval()  # 固定dropout和批次歸一化

with torch.no_grad():
    # val_seq_input = (235, 7, 1)
    val_seq_pred = best_model(val_x)
    # val_seq_pred = (235, 1)
    print(val_seq_pred.shape)
    pred_cases = scaler.inverse_transform(np.expand_dims(val_seq_pred.cpu().flatten().numpy(), axis=0)).flatten()
    # pred_cases = (235)
    print(pred_cases.shape)
# Out:
# torch.Size([51, 1])
# (51,)

# %%
# plt.plot(x, y, label='')  (x=日期, y=全球確診人數) (必須len(x)=len(y)對應)
plt.figure(figsize=(8,6))
plt.plot(daily_cases.index[:len(train_data)], scaler.inverse_transform(train_data).flatten(), label='Historical Daily Cases')  #已知確診人數
plt.plot(daily_cases.index[len(train_data): len(train_data)+len(val_data)], scaler.inverse_transform(val_data).flatten(), label='Real Daily Cases')  # 預測之label
plt.plot(daily_cases.index[len(train_data)+seq_length: len(train_data)+seq_length+len(pred_cases)], pred_cases, label='Predicted Daily Cases')  # 預測之Output
plt.title('Daily cases')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend()

# %% [markdown]
# ## 5.3_最後epoch模型->預測未來幾天病例
# ### (最佳模型 vs. 最後epoch模型)

# %%
# 加載模型
last_model = torch.load('last_model.pth')
last_model.eval()  # 固定dropout和批次歸一化

with torch.no_grad():
    # val_seq_input = (235, 7, 1)
    val_seq_pred = last_model(val_x)
    # val_seq_pred = (235, 1)
    last_pred_cases = scaler.inverse_transform(np.expand_dims(val_seq_pred.cpu().flatten().numpy(), axis=0)).flatten()
    # last_pred_cases = (235)
    
print(f'使用的模型評估指標 -> {performance_eval}')
# plt.plot(x, y, label='')  (x=日期, y=全球確診人數) (必須len(x)=len(y)對應)
plt.figure(figsize=(8,6))
plt.plot(daily_cases.index[:len(train_data)], scaler.inverse_transform(train_data).flatten(), label='Historical Daily Cases')  #已知確診人數
plt.plot(daily_cases.index[len(train_data): len(train_data)+len(val_data)], scaler.inverse_transform(val_data).flatten(), label='Real Daily Cases')  # 預測之label
plt.plot(daily_cases.index[len(train_data)+seq_length: len(train_data)+seq_length+len(pred_cases)], pred_cases, label='(Best Model) Predicted Daily Cases')  # 預測之Output
plt.plot(daily_cases.index[len(train_data)+seq_length: len(train_data)+seq_length+len(pred_cases)], last_pred_cases, label='(Last Model) Predicted Daily Cases')  # 預測之Output
plt.title('Daily cases')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend()
# Out:
# 使用的模型評估指標 -> MSE

# %% [markdown]
# ## 0_修改程式 (傳送門)
# - [數據分析](#1_數據分析)
#
#
# - [數據預處理](#2_數據預處理)
#
#
# - [main-LSTM模型](#3_建立模型-LSTM)
#
#
# - [main-訓練model](#4.1_訓練模型)
#
#
# - [main-調超參數](#4.2_訓練模型-設定超參數)
#
#
# - [預測未來幾天庫存量](#5.1_最佳模型->預測未來幾天庫存量)
